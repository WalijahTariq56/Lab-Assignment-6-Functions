# %%
def calculate_area(length, width):
  area = length * width
  return area

result = calculate_area(5, 3)
print(result)
# Out:
# 15

# %%
def greet(name):
  print("Hello, " + name + "!")

# %%
greet("Walijah")
# Out:
# Hello, Walijah!

# %%
import datetime as dt
def greet_with_time(name):
    current_time = dt.datetime.now() 
    print(f"Hello, {name}! The current time is {current_time}.")
greet_with_time("Walijah")
# Out:
# Hello, Walijah! The current time is 2025-12-02 09:56:28.779197.

# %%
def calculate_average(a, b, c):
    average = (a + b + c) / 3
    return average
result = calculate_average(10, 20, 30)
print("Average:", result)
# Out:
# Average: 20.0

# %%
def calculate_discount(price, discount=10):
    discounted_price = price - (price * discount / 100)
    return discounted_price
result = calculate_discount(1000)
print("Discounted Price:", result)
# Out:
# Discounted Price: 900.0

# %%
def print_info(name, age, city):
    print(f"Name: {name}")
    print(f"Age: {age}")
    print(f"City: {city}")
print_info(name="Walijah", age=19, city="Gujranwala")
# Out:
# Name: Walijah
# Age: 19
# City: Gujranwala

# %%
def find_max(*numbers):
    if not numbers:
        return None
    return max(numbers)
print(find_max(10, 20, 5, 40, 15))
print(find_max())
# Out:
# 40
# None
